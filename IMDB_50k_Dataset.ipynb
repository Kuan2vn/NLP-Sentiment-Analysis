# %%
# !python -m spacy download en_core_web_md
# Out:
# 2024-01-30 05:56:42.635529: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 05:56:42.635578: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-30 05:56:42.639509: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-30 05:56:42.662320: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-30 05:56:47.071055: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-30 05:56:49.837723: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-30 05:56:49.838358: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-30 05:56:49.838611: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Collecting en-core-web-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.6.0/en_core_web_md-3.6.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.1.4)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# # Load Dataset

# %% [markdown]
# Download Dataset: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Create the movie comment DataFrame and display the statistics
mcommentDF=pd.read_csv('/content/drive/MyDrive/StudyWork/Dataset/IMDB_dataset.csv')
mcommentDF['sentiment'] = mcommentDF['sentiment'].replace({'positive': 1, 'negative': 0})
mcommentDF = mcommentDF[['review','sentiment']].dropna()
axplot=mcommentDF.sentiment.value_counts().plot(kind='bar', colormap='Paired')
plt.show()

# %% [markdown]
# # Tokenize dataset

# %%
# Import spaCy
import spacy
# Load the spaCy NLP model
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# # Save Features

# %%
# Create movie comment sample and categories objects
movie_comment_exp = []
categories = []
# Perform Tokenization
for idx, rw in mcommentDF.iterrows():
  comments = rw["review"]
  rating = rw["sentiment"]
  categories.append(rating)
  mtoks = [token.text for token in nlp(comments)]
  movie_comment_exp.append(mtoks)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e7d2d8621795> in <cell line: 5>()
#       7   rating = rw["sentiment"]
#       8   categories.append(rating)
# ----> 9   mtoks = [token.text for token in nlp(comments)]
#      10   movie_comment_exp.append(mtoks)
#
# /usr/local/lib/python3.10/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1040                 error_handler = proc.get_error_handler()
#    1041             try:
# -> 1042                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1043             except KeyError as e:
#    1044                 # This typically happens if a component is not initialized
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.predict()
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# /usr/local/lib/python3.10/dist-packages/thinc/model.py in predict(self, X)
#     332         only the output, instead of the `(output, callback)` tuple.
#     333         """
# --> 334         return self._func(self, X, is_train=False)[0]
#     335
#     336     def finish_update(self, optimizer: Optimizer) -> None:
#
# /usr/local/lib/python3.10/dist-packages/spacy/ml/tb_framework.py in forward(model, X, is_train)
#      32
#      33 def forward(model, X, is_train):
# ---> 34     step_model = ParserStepModel(
#      35         X,
#      36         model.layers,
#
# /usr/local/lib/python3.10/dist-packages/spacy/ml/parser_model.pyx in spacy.ml.parser_model.ParserStepModel.__init__()
#
# /usr/local/lib/python3.10/dist-packages/spacy/ml/parser_model.pyx in spacy.ml.parser_model.precompute_hiddens.__init__()
#
# /usr/local/lib/python3.10/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     308         """Call the model's `forward` function, returning the output and a
#     309         callback to compute the gradients via backpropagation."""
# --> 310         return self._func(self, X, is_train=is_train)
#     311
#     312     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.10/dist-packages/spacy/ml/_precomputable_affine.py in forward(model, X, is_train)
#      25     # Preallocate array for layer output, including padding.
#      26     Yf = model.ops.alloc2f(X.shape[0] + 1, nF * nO * nP, zeros=False)
# ---> 27     model.ops.gemm(X, W.reshape((nF * nO * nP, nI)), trans2=True, out=Yf[1:])
#      28     Yf = Yf.reshape((Yf.shape[0], nF, nO, nP))
#      29
#
# KeyboardInterrupt:

# %%
features = dict(
    features = movie_comment_exp,
    categories=categories,
)

# %%
import pickle

# Lưu danh sách vào tệp
with open('feature.pkl', 'wb') as file:
    pickle.dump(features, file)

# %%
# !cp /content/feature.pkl -d /content/drive/MyDrive/StudyWork/Dataset

# %% [markdown]
# # Load Features

# %%
import pickle

# Đọc danh sách từ tệp
with open('/content/drive/MyDrive/StudyWork/Dataset/feature.pkl', 'rb') as file:
    loaded_list = pickle.load(file)

# %%
# loaded_list

movie_comment_exp = loaded_list['features']
categories = loaded_list['categories']

# %% [markdown]
# # Preprocess Data

# %%
# Import Tokenizer, pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
# Create ktoken and perform tokenization
ktoken = Tokenizer(lower=True)
ktoken.fit_on_texts(movie_comment_exp)
# Create utterance sequences object
seq_utterance = ktoken.texts_to_sequences(movie_comment_exp)

# %%
# Set the max length to 50
MLEN = 50
# Create pad utterance sequence object
ps_utterance = pad_sequences(seq_utterance, MLEN, padding="post")

# %%
# Convert the ps_utterance into numpy arrays
ps_utterance = np.array(ps_utterance)
# Create the category list (catlist)
catlist = np.array(categories)

# %%
catlist = catlist.reshape(catlist.shape[0] , 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Assume ps_utterance and catlist are processed data
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(ps_utterance, catlist, test_size=0.2, random_state=42)

# %% [markdown]
# # LSTM Model

# %%
# Import the LSTM model and the optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, Flatten
from tensorflow.keras import optimizers

# %%
utterance_input = Input(shape=(None,))

# %%
# Create the Embedding_Layer
embedding = Embedding(input_dim = len(ktoken.word_index)+1, output_dim = 100)(utterance_input)

# %%
# Create the LSTM_Layer
LSTM_layer = LSTM(units=256)(embedding)

# %%
# Create the Output Layer
outlayer = Dense(1, activation='sigmoid')(LSTM_layer)

# %%
# Create the IMDB User Review LSTM Model (imdb_mdl)
imdb_mdl = Model(inputs=[utterance_input],outputs=[outlayer])

# %%
imdb_mdl.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, None)]            0
#
#  embedding_7 (Embedding)     (None, None, 100)         14607300
#
#  lstm_11 (LSTM)              (None, 256)               365568
#
#  dense_16 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 14973125 (57.12 MB)
# Trainable params: 14973125 (57.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
imdb_mdl.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Model fitting by using 5 epochs
history = imdb_mdl.fit(x=X_train,
y=y_train,
batch_size=64,
epochs=30,
validation_split=0.2)
# Out:
# Epoch 1/30
# 500/500 [==============================] - 22s 38ms/step - loss: 0.4711 - accuracy: 0.7674 - val_loss: 0.3943 - val_accuracy: 0.8199
# Epoch 2/30
# 500/500 [==============================] - 10s 21ms/step - loss: 0.2726 - accuracy: 0.8880 - val_loss: 0.4445 - val_accuracy: 0.8090
# Epoch 3/30
# 500/500 [==============================] - 6s 12ms/step - loss: 0.1563 - accuracy: 0.9413 - val_loss: 0.6135 - val_accuracy: 0.7945
# Epoch 4/30
# 500/500 [==============================] - 6s 11ms/step - loss: 0.0870 - accuracy: 0.9693 - val_loss: 0.6561 - val_accuracy: 0.7951
# Epoch 5/30
# 500/500 [==============================] - 6s 12ms/step - loss: 0.0548 - accuracy: 0.9816 - val_loss: 0.8483 - val_accuracy: 0.7871
# Epoch 6/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0422 - accuracy: 0.9860 - val_loss: 0.7326 - val_accuracy: 0.7906
# Epoch 7/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0243 - accuracy: 0.9918 - val_loss: 1.0562 - val_accuracy: 0.7856
# Epoch 8/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0231 - accuracy: 0.9919 - val_loss: 1.0546 - val_accuracy: 0.7690
# Epoch 9/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 1.1475 - val_accuracy: 0.7732
# Epoch 10/30
# 500/500 [==============================] - 6s 11ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 1.1560 - val_accuracy: 0.7704
# Epoch 11/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0134 - accuracy: 0.9951 - val_loss: 1.1836 - val_accuracy: 0.7766
# Epoch 12/30
# 500/500 [==============================] - 6s 12ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 1.3494 - val_accuracy: 0.7761
# Epoch 13/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 1.2613 - val_accuracy: 0.7806
# Epoch 14/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 1.4157 - val_accuracy: 0.7778
# Epoch 15/30
# 500/500 [==============================] - 6s 11ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 1.5304 - val_accuracy: 0.7745
# Epoch 16/30
# 500/500 [==============================] - 6s 12ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 1.5256 - val_accuracy: 0.7788
# Epoch 17/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 1.6223 - val_accuracy: 0.7785
# Epoch 18/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 1.4938 - val_accuracy: 0.7772
# Epoch 19/30
# 500/500 [==============================] - 5s 11ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 1.5705 - val_accuracy: 0.7751
# Epoch 20/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 1.4147 - val_accuracy: 0.7705
# Epoch 21/30
# 500/500 [==============================] - 6s 11ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 1.6077 - val_accuracy: 0.7770
# Epoch 22/30
# 500/500 [==============================] - 6s 11ms/step - loss: 9.7881e-04 - accuracy: 0.9997 - val_loss: 1.7595 - val_accuracy: 0.7649
# Epoch 23/30
# 500/500 [==============================] - 5s 9ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 1.7424 - val_accuracy: 0.7768
# Epoch 24/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 1.2456 - val_accuracy: 0.7692
# Epoch 25/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 1.4537 - val_accuracy: 0.7765
# Epoch 26/30
# 500/500 [==============================] - 5s 10ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 1.4889 - val_accuracy: 0.7771
# Epoch 27/30
# 500/500 [==============================] - 5s 11ms/step - loss: 3.6510e-04 - accuracy: 0.9999 - val_loss: 1.7806 - val_accuracy: 0.7759
# Epoch 28/30
# 500/500 [==============================] - 5s 10ms/step - loss: 3.8925e-05 - accuracy: 1.0000 - val_loss: 1.9844 - val_accuracy: 0.7768
# Epoch 29/30
# 500/500 [==============================] - 5s 11ms/step - loss: 1.6692e-05 - accuracy: 1.0000 - val_loss: 2.0713 - val_accuracy: 0.7760
# Epoch 30/30
# 500/500 [==============================] - 5s 10ms/step - loss: 1.0442e-05 - accuracy: 1.0000 - val_loss: 2.1567 - val_accuracy: 0.7747

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
# plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Evalute LSTM

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = imdb_mdl.predict(X_test)
y_pred = np.round(y_pred)

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Confusion Matrix:
# [[3843 1118]
#  [1039 4000]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78      4961
#            1       0.78      0.79      0.79      5039
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.78     10000
# weighted avg       0.78      0.78      0.78     10000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Negative ', 'Positive'], yticklabels=['Negative ', 'Positive'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Dense

# %%
utterance_input = Input(shape=(None,))
embedding = Embedding(input_dim=len(ktoken.word_index) + 1, output_dim=100)(utterance_input)
dense_layer1 = Dense(128, activation='relu')(embedding)
dense_layer2 = Dense(64, activation='relu')(dense_layer1)
outlayer = Dense(1, activation='sigmoid')(dense_layer2)

dense_model = Model(inputs=[utterance_input], outputs=[outlayer])

# %%
dense_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 100)         14607300
#
#  dense (Dense)               (None, None, 128)         12928
#
#  dense_1 (Dense)             (None, None, 64)          8256
#
#  dense_2 (Dense)             (None, None, 1)           65
#
# =================================================================
# Total params: 14628549 (55.80 MB)
# Trainable params: 14628549 (55.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
dense_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Model fitting by using 5 epochs
dense_model.fit(x=ps_utterance,
y=catlist,
batch_size=64,
epochs=5,
validation_split=0.3)
# Out:
# Epoch 1/5
# 547/547 [==============================] - 35s 55ms/step - loss: 0.6812 - accuracy: 0.5474 - val_loss: 0.6779 - val_accuracy: 0.5547
# Epoch 2/5
# 547/547 [==============================] - 9s 16ms/step - loss: 0.6705 - accuracy: 0.5684 - val_loss: 0.6787 - val_accuracy: 0.5564
# Epoch 3/5
# 547/547 [==============================] - 8s 14ms/step - loss: 0.6646 - accuracy: 0.5717 - val_loss: 0.6829 - val_accuracy: 0.5564
# Epoch 4/5
# 547/547 [==============================] - 6s 11ms/step - loss: 0.6613 - accuracy: 0.5729 - val_loss: 0.6851 - val_accuracy: 0.5556
# Epoch 5/5
# 547/547 [==============================] - 6s 10ms/step - loss: 0.6594 - accuracy: 0.5736 - val_loss: 0.6887 - val_accuracy: 0.5562

# %% [markdown]
# # CNN + LSTM + DENSE

# %%
from keras.layers import Input, Embedding, Conv1D, MaxPooling1D, LSTM, Dense, BatchNormalization, Dropout, Activation
from keras.models import Model

# Define input shape
utterance_input = Input(shape=(None,))

# Embedding layer
embedding = Embedding(input_dim=len(ktoken.word_index) + 1, output_dim=100)(utterance_input)

# Convolutional layers
conv1d_1 = Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation='relu')(embedding)
maxpool_1 = MaxPooling1D(pool_size=2, strides=1, padding="valid")(conv1d_1)
conv1d_2 = Conv1D(filters=32, kernel_size=3, strides=1, padding='causal', activation='relu')(maxpool_1)
maxpool_2 = MaxPooling1D(pool_size=2, strides=1, padding="valid")(conv1d_2)

# LSTM layer
lstm_1 = LSTM(128, return_sequences=True)(maxpool_2)
lstm_2 = LSTM(128)(lstm_1)

# Dense layers
dense_layer1 = Dense(64)(lstm_2)
bn_dense_1 = BatchNormalization()(dense_layer1)
dropout_1 = Dropout(0.2)(bn_dense_1)
relu_1 = Activation('relu')(dropout_1)

dense_layer2 = Dense(16)(relu_1)
bn_dense_2 = BatchNormalization()(dense_layer2)
dropout_2 = Dropout(0.1)(bn_dense_2)
relu_2 = Activation('relu')(dropout_2)

# Output layer
outlayer = Dense(1, activation='sigmoid')(relu_2)

# Define the model
combined_model = Model(inputs=utterance_input, outputs=outlayer)

# %%
combined_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Model fitting by using 5 epochs
history = combined_model.fit(x=X_train,
y=y_train,
batch_size=64,
epochs=30,
validation_split=0.2)
# Out:
# Epoch 1/30
# 500/500 [==============================] - 28s 46ms/step - loss: 0.5180 - accuracy: 0.7346 - val_loss: 0.7057 - val_accuracy: 0.5910
# Epoch 2/30
# 500/500 [==============================] - 10s 20ms/step - loss: 0.2342 - accuracy: 0.9108 - val_loss: 0.7455 - val_accuracy: 0.7188
# Epoch 3/30
# 500/500 [==============================] - 9s 17ms/step - loss: 0.0968 - accuracy: 0.9676 - val_loss: 0.5592 - val_accuracy: 0.7770
# Epoch 4/30
# 500/500 [==============================] - 9s 17ms/step - loss: 0.0610 - accuracy: 0.9792 - val_loss: 1.5710 - val_accuracy: 0.6569
# Epoch 5/30
# 500/500 [==============================] - 9s 18ms/step - loss: 0.0457 - accuracy: 0.9846 - val_loss: 1.8067 - val_accuracy: 0.6555
# Epoch 6/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0319 - accuracy: 0.9892 - val_loss: 0.8037 - val_accuracy: 0.8030
# Epoch 7/30
# 500/500 [==============================] - 10s 20ms/step - loss: 0.0279 - accuracy: 0.9905 - val_loss: 5.3583 - val_accuracy: 0.5025
# Epoch 8/30
# 500/500 [==============================] - 9s 18ms/step - loss: 0.0294 - accuracy: 0.9894 - val_loss: 1.9893 - val_accuracy: 0.6870
# Epoch 9/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0268 - accuracy: 0.9904 - val_loss: 1.1680 - val_accuracy: 0.7606
# Epoch 10/30
# 500/500 [==============================] - 10s 20ms/step - loss: 0.0234 - accuracy: 0.9921 - val_loss: 1.1515 - val_accuracy: 0.7638
# Epoch 11/30
# 500/500 [==============================] - 8s 17ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 1.1968 - val_accuracy: 0.7714
# Epoch 12/30
# 500/500 [==============================] - 7s 15ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 3.3121 - val_accuracy: 0.6090
# Epoch 13/30
# 500/500 [==============================] - 9s 18ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 1.3788 - val_accuracy: 0.7690
# Epoch 14/30
# 500/500 [==============================] - 8s 17ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 6.9927 - val_accuracy: 0.5441
# Epoch 15/30
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 1.3003 - val_accuracy: 0.8027
# Epoch 16/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 1.6326 - val_accuracy: 0.7394
# Epoch 17/30
# 500/500 [==============================] - 9s 18ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 1.3129 - val_accuracy: 0.7837
# Epoch 18/30
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.9665 - val_accuracy: 0.8109
# Epoch 19/30
# 500/500 [==============================] - 8s 17ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 1.0536 - val_accuracy: 0.8009
# Epoch 20/30
# 500/500 [==============================] - 9s 17ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 1.3165 - val_accuracy: 0.7960
# Epoch 21/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 1.1814 - val_accuracy: 0.8014
# Epoch 22/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 1.2069 - val_accuracy: 0.7876
# Epoch 23/30
# 500/500 [==============================] - 7s 15ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 1.7591 - val_accuracy: 0.7790
# Epoch 24/30
# 500/500 [==============================] - 10s 20ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 2.9682 - val_accuracy: 0.6924
# Epoch 25/30
# 500/500 [==============================] - 9s 19ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 1.5128 - val_accuracy: 0.7977
# Epoch 26/30
# 500/500 [==============================] - 9s 17ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 1.7839 - val_accuracy: 0.7563
# Epoch 27/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 1.9520 - val_accuracy: 0.7738
# Epoch 28/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 1.5587 - val_accuracy: 0.7990
# Epoch 29/30
# 500/500 [==============================] - 8s 16ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 1.0993 - val_accuracy: 0.8101
# Epoch 30/30
# 500/500 [==============================] - 10s 19ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 1.6664 - val_accuracy: 0.8005

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
# plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Evaluate Combined Model

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = combined_model.predict(X_test)
y_pred = np.round(y_pred)

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 313/313 [==============================] - 2s 6ms/step
# Confusion Matrix:
# [[3654 1307]
#  [ 643 4396]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79      4961
#            1       0.77      0.87      0.82      5039
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.80      0.80     10000
# weighted avg       0.81      0.81      0.80     10000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Negative ', 'Positive'], yticklabels=['Negative ', 'Positive'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Assume ps_utterance and catlist are processed data
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(ps_utterance, catlist, test_size=0.2, random_state=42)

# %%
# Create a Logistic Regression model
logreg_model = LogisticRegression()

# Train the model on the training set
logreg_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Make predictions on the testing set
y_pred = logreg_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5086

# %%
# Make predictions on the testing set
y_pred = logreg_model.predict(X_train)

# Evaluate the model
accuracy = accuracy_score(y_train, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.516025

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Xây dựng mô hình Random Forest
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
# Out:
# <ipython-input-15-b8412bd52cd8>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_model.fit(X_train, y_train)
# RandomForestClassifier()

# %%
# Dự đoán trên tập kiểm tra
y_pred_rf = rf_model.predict(X_test)

# Đánh giá hiệu suất
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy:", accuracy_rf)
# Out:
# Random Forest Accuracy: 0.5399

# %%
# Dự đoán trên tập kiểm tra
y_pred_rf = rf_model.predict(X_train)

# Đánh giá hiệu suất
accuracy_rf = accuracy_score(y_train, y_pred_rf)
print("Random Forest Accuracy:", accuracy_rf)
# Out:
# Random Forest Accuracy: 0.999975

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# Xây dựng mô hình Naive Bayes
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MultinomialNB()

# %%
# Dự đoán trên tập kiểm tra
y_pred_nb = nb_model.predict(X_test)

# Đánh giá hiệu suất
accuracy_nb = accuracy_score(y_test, y_pred_nb)
print("Naive Bayes Accuracy:", accuracy_nb)
# Out:
# Naive Bayes Accuracy: 0.5031

# %%
# Dự đoán trên tập kiểm tra
y_pred_nb = nb_model.predict(X_train)

# Đánh giá hiệu suất
accuracy_nb = accuracy_score(y_train, y_pred_nb)
print("Naive Bayes Accuracy:", accuracy_nb)
# Out:
# Naive Bayes Accuracy: 0.5152
